# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df1=pd.read_csv('p1_ff.csv')

# %%
df2=pd.read_csv('p2_ff.csv')

# %%
df1
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 117   26      9  2012           31   54   11    0.0  82.0  6.0  16.3  2.5
# 118   27      9  2012           31   66   11    0.0  85.7  8.3  24.9  4.0
# 119   28      9  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29      9  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30      9  2012           25   78   14    1.4  45.0  1.9   7.5  0.2
#
#      BUI  FWI  Fire
# 0    3.4  0.5     0
# 1    3.9  0.4     0
# ...

# %%
df1['Region']=0

# %%
df1
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 117   26      9  2012           31   54   11    0.0  82.0  6.0  16.3  2.5
# 118   27      9  2012           31   66   11    0.0  85.7  8.3  24.9  4.0
# 119   28      9  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29      9  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30      9  2012           25   78   14    1.4  45.0  1.9   7.5  0.2
#
#      BUI  FWI  Fire  Region
# 0    3.4  0.5     0       0
# ...

# %%
df2['Region']=1

# %%
df=pd.concat([df1, df2], axis=0, ignore_index=True)

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI  Fire  Region
# 0     3.4  0.5     0       0
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Fire', 'Region'],
#       dtype='object')

# %%
# TO remove blankspaces from names

# %%
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Fire', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  Fire         244 non-null    int64
#  14  Region       244 non-null    int64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 28.7+ KB

# %%
df.drop(165,inplace=True)
df['DC']=df['DC'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    object
#  13  Fire         243 non-null    int64
#  14  Region       243 non-null    int64
# dtypes: float64(6), int64(8), object(1)
# memory usage: 30.4+ KB

# %%
df[df['FWI'].str.isnumeric()==True]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC     DC   ISI  \
# 125    4      6  2012           30  64  14   0.0  79.4   5.2   15.4   2.2
# 128    7      6  2012           35  44  17   0.2  85.6   9.9   28.9   5.4
# 131   10      6  2012           30  41  15   0.0  89.4  13.3   22.5   8.4
# 148   27      6  2012           36  55  15   0.0  89.1  20.9   43.3   8.0
# 156    5      7  2012           34  45  18   0.0  90.5  18.7   46.4  11.3
# 159    8      7  2012           35  47  18   6.0  80.8   9.8    9.7   3.1
# 170   19      7  2012           34  58  16   0.0  88.1  27.8   61.1   7.3
# 172   21      7  2012           36  29  18   0.0  93.9  39.6   80.6  18.5
# 177   26      7  2012           35  58  10   0.2  78.3  10.8   19.7   1.6
# 179   28      7  2012           33  57  16   0.0  87.5  15.7   37.6   6.7
# 199   17      8  2012           42  24   9   0.0  96.0  30.3   76.4  15.7
# 202   20      8  2012           36  81  15   0.0  83.7  34.4  107.0   3.8
# ...

# %%
df['FWI']=df['FWI'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Fire         243 non-null    int64
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(8)
# memory usage: 30.4 KB

# %%
df.to_csv('final_ff.csv',index=False)

# %%
df_copy=df.drop(['day','month','year'],axis=1)

# %%
plt.style.use('seaborn')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# /tmp/ipykernel_91/1062445420.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
percentage=df_copy['Fire'].value_counts(normalize=True)*100

# %%
classlabels=['Fire','Not Fire']
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title('Pie Chart')
plt.show()

# %%
## mULTICOLLINEARITY 
'''
When there is a covariance between two or more independent features above a threshold
in a dataset then for feature selection we can consider of the the two and exclude the other
'''
# Out:
# '\nWhen there is a covariance between two or more independent features above a threshold\nin a dataset then for feature selection we can consider of the the two and exclude the other\n'

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Fire  Region
# ...

# %%
df['X']=df['Fire']

# %%
df['Fire']=df['Region']

# %%
df['Region']=df['X']

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Fire  Region  X
# ...

# %%
df.drop('X',axis=1,inplace=True)

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Fire  Region
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.iloc[:,:-1]# Independent features

# %%
y=df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=10)

# %%
X_train
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC     DC   ISI  \
# 1      2      6  2012           29  61  13   1.3  64.4   4.1    7.6   1.0
# 2      3      6  2012           26  82  22  13.1  47.1   2.5    7.1   0.3
# 149   28      6  2012           37  37  13   0.0  92.5  27.2   52.4  11.7
# 209   27      8  2012           36  54  14   0.0  91.0  65.9  177.3  10.0
# 103   12      9  2012           29  88  13   0.0  71.0   2.6   16.6   1.2
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...    ...   ...
# 64     4      8  2012           34  69  13   0.0  85.0   8.2   19.8   4.0
# 15    16      6  2012           29  89  13   0.7  36.1   1.7    7.6   0.0
# 229   16      9  2012           33  26  13   0.0  93.9  21.2   59.2  14.2
# 125    4      6  2012           30  64  14   0.0  79.4   5.2   15.4   2.2
# 9     10      6  2012           28  79  12   0.0  73.2   9.5   46.3   1.3
#
#       BUI   FWI  Fire
# 1     3.9   0.4     0
# 2     2.7   0.1     0
# ...

# %%
def correlation(dataset,thres):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>thres:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation(X_train,0.85)

# %%
corr_features
# Out:
# {'BUI', 'DC', 'FWI'}

# %%
df.corr()
# Out:
#                   day     month  year  Temperature        RH        Ws  \
# day          1.000000 -0.000369   NaN     0.097227 -0.076034  0.047812
# month       -0.000369  1.000000   NaN    -0.056781 -0.041252 -0.039880
# year              NaN       NaN   NaN          NaN       NaN       NaN
# Temperature  0.097227 -0.056781   NaN     1.000000 -0.651400 -0.284510
# RH          -0.076034 -0.041252   NaN    -0.651400  1.000000  0.244048
# Ws           0.047812 -0.039880   NaN    -0.284510  0.244048  1.000000
# Rain        -0.112523  0.034822   NaN    -0.326492  0.222356  0.171506
# FFMC         0.224956  0.017030   NaN     0.676568 -0.644873 -0.166548
# DMC          0.491514  0.067943   NaN     0.485687 -0.408519 -0.000721
# DC           0.527952  0.126511   NaN     0.376284 -0.226941  0.079135
# ISI          0.180543  0.065608   NaN     0.603871 -0.686667  0.008532
# BUI          0.517117  0.085073   NaN     0.459789 -0.353841  0.031438
# ...

# %%
X_train.drop(['BUI','DC'],axis=1,inplace=True)
X_test.drop(['BUI','DC'],axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 12), (61, 12))

# %%
X_train.drop(['day','month','year'],axis=1,inplace=True)

# %%
X_test.drop(['day','month','year'],axis=1,inplace=True)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso=Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred=lasso.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print('Mean absolute error',mae)
print('R2_score',score)
# Out:
# Mean absolute error 0.4891911367321204
# R2_score -0.026567150630444125
